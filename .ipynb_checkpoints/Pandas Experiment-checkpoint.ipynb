# %%
import pandas as pd
import numpy as np
from collections import Counter
import re 
import nltk
import string
from nltk.corpus import stopwords

# %%
working_df = pd.read_csv('/Users/noahcg/Desktop/complaintDocumentREEs/masterFile.csv')

working_df= working_df.dropna()

# %%
all_categories = working_df['category'].values
unique_cat = np.unique(all_categories)

# %%
def text_parser(block, cnt):
    #Better text parsing code here
    
    shortword = re.compile(r'\W*\b\w{1,3}\b')
    block = shortword.sub('', block)
    
    lst_of_tokens = block.split(' ')
    
    lst_of_tokens = [w.lower() for w in lst_of_tokens]
    
    table = str.maketrans('', '', string.punctuation)
    lst_of_tokens = [w.translate(table) for w in lst_of_tokens]
    
    lst_of_tokens = [token for token in lst_of_tokens if token.isalpha()]
    
    stop_words = set(stopwords.words('english'))
    lst_of_tokens = [w for w in lst_of_tokens if not w in stop_words]
    lst_of_tokens.sort()
    
    for i in lst_of_tokens:
        cnt[i] +=1
    return cnt

# %%
selected_cols_df = working_df[['category','text_content']]
category_dict = dict()
category_counter_dict = dict()

for category in unique_cat:
    category_counter_dict[category] = Counter()

for i in range(len(selected_cols_df.values)): #iterating through all the rows in the selected cols
    #Have text content, with its associated category
    category = selected_cols_df.values[i][0]
    content = selected_cols_df.values[i][1]
    category_counter_dict[category] = text_parser(content, category_counter_dict[category]) #Do a frequency count of the content. #Should return the top used words. 
    
for category in unique_cat:
    if category in category_dict:
        for val in category_counter_dict[category].most_common(20):
            category_dict[category].append(val)    
    else:
        category_dict[category] = []
        for val in category_counter_dict[category].most_common(20):
            category_dict[category].append(val)

# %%
category_dict
# Out:
# {'Bribery / Official Corruption': [('officer', 162),
#   ('police', 160),
#   ('department', 106),
#   ('board', 73),
#   ('information', 69),
#   ('martin', 64),
#   ('personal', 56),
#   ('marcos', 55),
#   ('chicago', 54),
#   ('respondent', 52),
#   ('case', 41),
#   ('hernandez', 40),
#   ('jennifer', 38),
#   ('evidence', 35),
#   ('leads', 35),
#   ('star', 34),
#   ('conduct', 34),
#   ('official', 32),
#   ('durso', 31),
#   ('superintendent', 30)],
#  'Conduct Unbecoming (Off-Duty)': [('police', 288),
#   ('board', 209),
#   ('officer', 199),
#   ('accused', 152),
#   ('department', 124),
#   ('report', 124),
#   ('respondent', 123),
#   ('case', 117),
#   ('chicago', 103),
#   ('sergeant', 82),
#   ('charges', 80),
#   ('investigation', 75),
#   ('city', 68),
#   ('hearing', 66),
#   ('evidence', 63),
#   ('address', 62),
#   ('star', 62),
#   ('stated', 62),
#   ('superintendent', 59),
#   ('unit', 56)],
#  'Criminal Misconduct': [('police', 686),
#   ('personal', 520),
#   ('officer', 399),
#   ('info', 328),
#   ('department', 282),
#   ('report', 278),
#   ('board', 272),
#   ('accused', 233),
#   ('time', 190),
#   ('star', 186),
#   ('chicago', 182),
#   ('respondent', 178),
#   ('case', 176),
#   ('charges', 166),
#   ('unit', 166),
#   ('date', 160),
#   ('investigation', 158),
#   ('john', 152),
#   ('kaporis', 142),
#   ('sergeant', 136)],
#  'Domestic': [('officer', 1428),
#   ('police', 958),
#   ('stated', 596),
#   ('report', 509),
#   ('civilian', 497),
#   ('incident', 403),
#   ('time', 331),
#   ('star', 315),
#   ('date', 310),
#   ('department', 301),
#   ('subject', 297),
#   ('sergeant', 292),
#   ('accused', 276),
#   ('duty', 268),
#   ('chicago', 251),
#   ('unit', 249),
#   ('professional', 245),
#   ('board', 244),
#   ('sustained', 241),
#   ('investigation', 240)],
#  'Drug / Alcohol Abuse': [('police', 278),
#   ('officer', 274),
#   ('board', 245),
#   ('respondent', 143),
#   ('department', 114),
#   ('chicago', 106),
#   ('charges', 104),
#   ('case', 92),
#   ('hearing', 77),
#   ('evidence', 72),
#   ('city', 69),
#   ('rule', 64),
#   ('superintendent', 61),
#   ('star', 57),
#   ('hariri', 55),
#   ('guilty', 49),
#   ('findings', 43),
#   ('upon', 43),
#   ('conduct', 39),
#   ('violating', 39)],
#  'Excessive Force': [('officer', 1337),
#   ('police', 580),
#   ('subject', 538),
#   ('weapon', 407),
#   ('vehicle', 364),
#   ('rialmo', 345),
#   ('stated', 341),
#   ('member', 314),
#   ('force', 293),
#   ('time', 286),
#   ('incident', 281),
#   ('fired', 276),
#   ('diaz', 269),
#   ('name', 237),
#   ('report', 235),
#   ('jaguar', 227),
#   ('department', 224),
#   ('shot', 205),
#   ('shots', 205),
#   ('chicago', 189)],
#  'False Arrest': [('police', 1203),
#   ('officer', 1199),
#   ('subject', 1163),
#   ('date', 794),
#   ('report', 746),
#   ('accused', 720),
#   ('arrest', 676),
#   ('name', 631),
#   ('department', 593),
#   ('unit', 593),
#   ('time', 557),
#   ('investigation', 543),
#   ('stated', 519),
#   ('vehicle', 519),
#   ('star', 505),
#   ('officers', 494),
#   ('chicago', 416),
#   ('civilian', 414),
#   ('complainant', 410),
#   ('arrested', 406)],
#  'Illegal Search': [('police', 2338),
#   ('accused', 1929),
#   ('unit', 1720),
#   ('date', 1714),
#   ('report', 1660),
#   ('department', 1446),
#   ('complainant', 1418),
#   ('officer', 1403),
#   ('investigation', 1284),
#   ('time', 1255),
#   ('star', 1159),
#   ('advised', 967),
#   ('counsel', 957),
#   ('name', 921),
#   ('statement', 899),
#   ('search', 875),
#   ('examination', 868),
#   ('member', 839),
#   ('complaint', 836),
#   ('chicago', 829)],
#  'Lockup Procedures': [('officer', 315),
#   ('police', 301),
#   ('complainant', 291),
#   ('accused', 283),
#   ('report', 250),
#   ('unit', 232),
#   ('date', 211),
#   ('department', 205),
#   ('subject', 184),
#   ('time', 173),
#   ('member', 171),
#   ('detective', 171),
#   ('related', 144),
#   ('star', 140),
#   ('incident', 137),
#   ('advised', 136),
#   ('duty', 133),
#   ('investigation', 132),
#   ('name', 118),
#   ('area', 117)],
#  'Operation/Personnel Violations': [('police', 4115),
#   ('officer', 3026),
#   ('report', 2516),
#   ('accused', 2188),
#   ('department', 1900),
#   ('date', 1628),
#   ('time', 1559),
#   ('complainant', 1545),
#   ('star', 1540),
#   ('unit', 1442),
#   ('board', 1323),
#   ('investigation', 1272),
#   ('chicago', 1270),
#   ('sergeant', 1141),
#   ('stated', 1126),
#   ('case', 1085),
#   ('incident', 992),
#   ('duty', 976),
#   ('member', 935),
#   ('evidence', 934)],
#  'Racial Profiling': [('police', 10),
#   ('review', 9),
#   ('board', 8),
#   ('administrator', 7),
#   ('chicago', 7),
#   ('chief', 6),
#   ('officer', 6),
#   ('member', 5),
#   ('superintendent', 5),
#   ('january', 4),
#   ('allegation', 3),
#   ('director', 3),
#   ('executive', 3),
#   ('matthew', 3),
#   ('pursuant', 3),
#   ('received', 3),
#   ('recommendation', 3),
#   ('recommended', 3),
#   ('request', 3),
#   ('reviewing', 3)],
#  'Supervisory Responsibilities': [('court', 1232),
#   ('right', 707),
#   ('police', 647),
#   ('time', 522),
#   ('witness', 489),
#   ('room', 425),
#   ('detective', 421),
#   ('told', 383),
#   ('said', 380),
#   ('like', 365),
#   ('department', 354),
#   ('tracy', 341),
#   ('officer', 329),
#   ('know', 324),
#   ('okay', 307),
#   ('report', 303),
#   ('statement', 290),
#   ('member', 285),
#   ('magers', 284),
#   ('home', 283)],
#  'Traffic': [('vehicle', 417),
#   ('police', 324),
#   ('officer', 258),
#   ('department', 256),
#   ('pursuit', 222),
#   ('unit', 220),
#   ('assigned', 146),
#   ('date', 146),
#   ('accused', 138),
#   ('received', 138),
#   ('report', 129),
#   ('time', 129),
#   ('robinson', 123),
#   ('chicago', 110),
#   ('misc', 107),
#   ('violation', 104),
#   ('star', 98),
#   ('rhea', 96),
#   ('traffic', 83),
#   ('investigation', 81)],
#  'Unknown': [('arrest', 29),
#   ('police', 27),
#   ('report', 25),
#   ('generated', 21),
#   ('department', 19),
#   ('beat', 18),
#   ('information', 17),
#   ('brian', 16),
#   ('date', 15),
#   ('killen', 15),
#   ('chicago', 13),
#   ('page', 13),
#   ('july', 12),
#   ('park', 12),
#   ('properties', 11),
#   ('arresting', 10),
#   ('facility', 10),
#   ('lockup', 10),
#   ('officer', 10),
#   ('system', 10)],
#  'Use Of Force': [('officer', 9139),
#   ('police', 7761),
#   ('subject', 4896),
#   ('report', 4464),
#   ('stated', 3903),
#   ('time', 3395),
#   ('date', 3388),
#   ('incident', 3374),
#   ('department', 3178),
#   ('unit', 2619),
#   ('chicago', 2430),
#   ('review', 2406),
#   ('officers', 2385),
#   ('accused', 2370),
#   ('member', 2341),
#   ('vehicle', 2054),
#   ('star', 2037),
#   ('name', 2031),
#   ('sustained', 2005),
#   ('related', 1950)],
#  'Verbal Abuse': [('officer', 778),
#   ('police', 614),
#   ('subject', 556),
#   ('accused', 392),
#   ('report', 366),
#   ('stated', 340),
#   ('unit', 322),
#   ('date', 312),
#   ('complainant', 296),
#   ('time', 278),
#   ('department', 236),
#   ('incident', 234),
#   ('star', 213),
#   ('related', 203),
#   ('review', 201),
#   ('sustained', 194),
#   ('member', 191),
#   ('officers', 185),
#   ('investigation', 182),
#   ('allegation', 172)]}
